# %%
# %reset -f

import os
import numpy as np
import pandas as pd
import random
import math
from math import e

import matplotlib
import matplotlib.pyplot as plt
import configparser

from matplotlib.ticker import MaxNLocator
from matplotlib.ticker import FuncFormatter

# %%
working_dir="../Analysis/"
pathoutput = working_dir
solini = pd.read_csv(working_dir + "solini.csv", sep=',', decimal='.')
solfin = pd.read_csv(working_dir + "solfin.csv", sep=',', decimal='.')
avance = pd.read_csv(working_dir + "avance.csv", sep=',', decimal='.')
control = pd.read_csv(working_dir + "control.csv", sep=',', decimal='.')

# %%
# histograma factor de utilización - solini
fig, ax = plt.subplots()
plt.hist(solini['futi_nt'], bins=30)
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
plt.ylabel('cantidad de trafos')
plt.xlabel('factor utilización')
plt.title('histograma factor de utilización - solución inicial')
plt.grid(True)

# %%
# histograma factor de utilización - solini
fig, ax = plt.subplots()
plt.hist(solfin['futi_nt'], bins=30)
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
plt.ylabel('cantidad de trafos')
plt.xlabel('factor utilización')
plt.title('histograma factor de utilización - solución final')
plt.grid(True)

# %%
# histograma pérdidas en hierro - solini
fig, ax = plt.subplots()
plt.hist(solini['pfeW'], bins=30)
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
plt.ylabel('cantidad de trafos')
plt.xlabel('pérdidas en el hierro [W/mes]')
plt.title('histograma pérdidas en hierro - solución inicial')
plt.grid(True)

# %%
# histograma pérdidas en hierro - solfin
fig, ax = plt.subplots()
plt.hist(solfin['pfeW'], bins=30)
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
plt.ylabel('cantidad de trafos')
plt.xlabel('pérdidas en el hierro [W/mes]')
plt.title('histograma pérdidas en hierro - solución final')
plt.grid(True)

# %%
# histograma pérdidas en cobre - solini
fig, ax = plt.subplots()
plt.hist(solini['pcuW'], bins=30)
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
plt.ylabel('cantidad de trafos')
plt.xlabel('pérdidas en el cobre [W/mes]')
plt.title('histograma pérdidas en cobre - solución inicial')
plt.grid(True)

# %%
# histograma pérdidas en cobre - solfin
fig, ax = plt.subplots()
plt.hist(solfin['pcuW'], bins=30)
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
plt.ylabel('cantidad de trafos')
plt.xlabel('pérdidas en el cobre [W/mes]')
plt.title('histograma pérdidas en cobre - solución final')
plt.grid(True)

# %%
# histograma pérdidas en totales - solini
fig, ax = plt.subplots()
plt.hist(solini['cpt_nt'], bins=30)
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
plt.ylabel('cantidad de trafos')
plt.xlabel('pérdidas de transformación [$/mes]')
plt.title('histograma pérdidas de transformación - solución inicial')
plt.grid(True)

# %%
# histograma pérdidas en totales - solini
fig, ax = plt.subplots()
plt.hist(solfin['cpt_nt'], bins=30)
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
plt.ylabel('cantidad de trafos')
plt.xlabel('pérdidas de transformación [$/mes]')
plt.title('histograma pérdidas de transformación - solución final')
plt.grid(True)

# %%
#avance
ax = avance.plot(y='csol')
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
ax.set_yticklabels(['{:,}'.format(int(x)) for x in ax.get_yticks().tolist()])
ax.legend_.remove()
plt.ylabel('$ / mes')
plt.xlabel('mejor red')
plt.title('evolución de las soluciones encontradas')
plt.grid(True)

# %%
#control
ax = control.plot(x='parejas', y='csol')
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
ax.set_yticklabels(['{:,}'.format(int(x)) for x in ax.get_yticks().tolist()])
ax.legend_.remove()
plt.ylabel('$ / mes')
plt.xlabel('red')
plt.title('evolución del costo de la red')
plt.grid(True)
